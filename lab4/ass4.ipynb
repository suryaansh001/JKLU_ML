# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('profits.txt')
print(data)

print(data.shape)
print(data.describe())
print(data.dtypes)
print(data.info())
# Out:
#      6.1101    17.592
# 0    5.5277   9.13020
# 1    8.5186  13.66200
# 2    7.0032  11.85400
# 3    5.8598   6.82330
# 4    8.3829  11.88600
# ..      ...       ...
# 91   5.8707   7.20290
# 92   5.3054   1.98690
# 93   8.2934   0.14454
# 94  13.3940   9.05510
# 95   5.4369   0.61705
#
# [96 rows x 2 columns]
# (96, 2)
#           6.1101     17.592
# count  96.000000  96.000000
# mean    8.181151   5.716709
# std     3.884451   5.404947
# min     5.026900  -2.680700
# 25%     5.690950   1.952550
# 50%     6.735950   4.455300
# 75%     8.639925   6.879150
# max    22.203000  24.147000
# 6.1101    float64
# 17.592    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   6.1101  96 non-null     float64
#  1   17.592  96 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB
# None

# %%
data.columns=['pop','profit']
print(data)
# Out:
#         pop    profit
# 0    5.5277   9.13020
# 1    8.5186  13.66200
# 2    7.0032  11.85400
# 3    5.8598   6.82330
# 4    8.3829  11.88600
# ..      ...       ...
# 91   5.8707   7.20290
# 92   5.3054   1.98690
# 93   8.2934   0.14454
# 94  13.3940   9.05510
# 95   5.4369   0.61705
#
# [96 rows x 2 columns]

# %%
plt.scatter(data['pop'],data['profit'])
plt.xlabel('popularion of city')
plt.ylabel('profit')
plt.show()

# %%
class MylinearRegression:
    def __init__(self,feature_mat,Y):
        self.total_iter=10
        self.learning_rate=0.01
        if len(feature_mat.shape) >=1:
            self.n=feature_mat.shape[1]
        else:
            n=1
        self.params=np.zeros((n+1))

        # self.feature_mat np.ones concat with self.feature_mat
        self.feature_mat=np.c_[np.ones(feature_mat.shape[0]),feature_mat]
        self.Y=Y

    def calc_h_theta_x(self,feature_mat):
        return np.dot(feature_mat,self.params)
    def calculatecost(self):
        return np.sum(np.square(self.calc_h_theta_x(self.feature_mat)-self.Y))/(2*self.feature_mat.shape[0])

# %%
total_iter=10
eta=0.01


def updatetheta(theta,feature_mat,Y):
    return theta-eta*(np.dot((np.dot(feature_mat,theta)-Y),feature_mat.T)/feature_mat.shape[0])
def costfncalc(theta,feature_mat,Y):
    return np.sum(np.square(np.dot(theta,feature_mat)-Y))/(2*feature_mat.shape[0])
def gradient_descent(theta,feature_mat,Y):
    for i in range(total_iter):
        theta=updatetheta(theta,feature_mat,Y)
    return theta



if len(data.shape) >=1:
    n=data.shape[0]
    print(n)
else:
    n=1
theta=np.zeros((n+1))
# print(theta)

feature_mat=np.ones(data.shape[0])
feature_mat=np.c_[feature_mat,data['pop']]
print(feature_mat)
Y=data['profit']

for i in range(total_iter):
    theta=updatetheta(theta,feature_mat,Y)

print(theta)

print(data.shape[0])
# Out:
# 96
# [[ 1.      5.5277]
#  [ 1.      8.5186]
#  [ 1.      7.0032]
#  [ 1.      5.8598]
#  [ 1.      8.3829]
#  [ 1.      7.4764]
#  [ 1.      8.5781]
#  [ 1.      6.4862]
#  [ 1.      5.0546]
#  [ 1.      5.7107]
#  [ 1.     14.164 ]
#  [ 1.      5.734 ]
#  [ 1.      8.4084]
#  [ 1.      5.6407]
#  [ 1.      5.3794]
#  [ 1.      6.3654]
#  [ 1.      5.1301]
#  [ 1.      6.4296]
#  [ 1.      7.0708]
#  [ 1.      6.1891]
#  [ 1.     20.27  ]
#  [ 1.      5.4901]
#  [ 1.      6.3261]
#  [ 1.      5.5649]
#  [ 1.     18.945 ]
#  [ 1.     12.828 ]
#  [ 1.     10.957 ]
#  [ 1.     13.176 ]
#  [ 1.     22.203 ]
#  [ 1.      5.2524]
#  [ 1.      6.5894]
#  [ 1.      9.2482]
#  [ 1.      5.8918]
#  [ 1.      8.2111]
#  [ 1.      7.9334]
#  [ 1.      8.0959]
#  [ 1.      5.6063]
#  [ 1.     12.836 ]
#  [ 1.      6.3534]
#  [ 1.      5.4069]
#  [ 1.      6.8825]
#  [ 1.     11.708 ]
#  [ 1.      5.7737]
#  [ 1.      7.8247]
#  [ 1.      7.0931]
#  [ 1.      5.0702]
#  [ 1.      5.8014]
# ...

# %%
import numpy as np
import pandas as pd

# Load df from text file
df = pd.read_csv('profits.txt', header=None)

# Assign column names
df.columns = ['pop', 'prof']

# Parameters
total_iter = 100
learning_rate = 0.01

def updatetheta(theta, pop_mat, Y):
    return theta - learning_rate * (np.dot(pop_mat.T, (np.dot(pop_mat, theta) - Y)) / pop_mat.shape[0])

def costfncalc(theta, pop_mat, Y):
    cosst=np.sum(np.square(np.dot(pop_mat, theta) - Y)) / (2 * pop_mat.shape[0])
    costs.append(cosst)
    return cosst

def gradient_descent(theta, pop_mat, Y):
    for i in range(total_iter):
        theta = updatetheta(theta, pop_mat, Y)
        thetavals.append(theta)
    return theta
costs=[]
thetavals=[]


m = df.shape[0]
pop_mat = np.c_[np.ones(m), df['pop']]
Y = df['prof']
theta = np.zeros(pop_mat.shape[1])
print("Theta:", theta)

# Perform gradient descent
theta = gradient_descent(theta, pop_mat, Y)

print("Theta:", theta)
print("Cost:", costfncalc(theta, pop_mat, Y))
# Out:
# Theta: [0. 0.]
# Theta: [-0.57655623  0.85958153]
# Cost: 5.479975580535112

# %%
# def graph_cost_vs_iterations(theta, pop_mat, Y, total_iter):
#     costs = []
#     for i in range(total_iter):
#         theta = updatetheta(theta, pop_mat, Y)
#         costs.append(costfncalc(theta, pop_mat, Y))
#     return costs

# plt.plot(range(total_iter), costs)
# plt.xlabel('Iterations')
# plt.ylabel('Cost')
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('profits.txt', header=None)

df.columns = ['pop', 'prof']


total_iter = 100
learning_rate = 0.01

def updatetheta(theta, pop_mat, Y):
    return theta - learning_rate * (np.dot(pop_mat.T, (np.dot(pop_mat, theta) - Y)) / pop_mat.shape[0])

def costfncalc(theta, pop_mat, Y):
    cosst = np.sum(np.square(np.dot(pop_mat, theta) - Y)) / (2 * pop_mat.shape[0])
    
    return cosst

def gradient_descent(theta, pop_mat, Y):
    for i in range(total_iter):
    
        theta = updatetheta(theta, pop_mat, Y)
        if i==0:
            #i=0 meansoneiterationdone
            first_iter_grad=theta
        
        
    return theta



# def graph_cost_vs_iterations(theta, pop_mat, Y, total_iter):
#     costs = np.array([])
#     for i in range(total_iter):
#         theta = updatetheta(theta, pop_mat, Y)
#         costs = np.append(costs, costfncalc(theta, pop_mat, Y))
        
#     return costs

# costs = graph_cost_vs_iterations(theta, pop_mat, Y, total_iter)
# print(costs)



m = df.shape[0]
pop_mat=np.c_[np.ones(m), df['pop']]
Y = df['prof']
#declaring theta as zero  because its bias + theta1*x
theta1=np.zeros(pop_mat.shape[1])
# bias=  np.zeros(pop_mat.shape[1])


# # Perform gradient descent
# theta = gradient_descent(theta, pop_mat, Y)

# print("Theta:", theta)
# print("Cost:", costfncalc(theta, pop_mat, Y))

# %%
def graph_cost_vs_iterations(theta, pop_mat,Y,total_iter):
    costs =[]
    thetas=[]
    for i in range(total_iter):
        theta = updatetheta(theta,pop_mat,Y)
        thetas.append(theta)
        costs.append(costfncalc(theta,pop_mat,Y))  
        
    return costs  ,thetas

costs,thetas = graph_cost_vs_iterations(theta,pop_mat,Y,total_iter)

print("cost function values are :",costs)
print("theta  aka weights values are :",thetas)
x=range(total_iter)

plt.plot(x, costs)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()
# Out:
# cost function values are : [np.float64(6.737190464870006), np.float64(5.9315935686049555), np.float64(5.901154707081388), np.float64(5.895228586444221), np.float64(5.8900949431173295), np.float64(5.885004158443647), np.float64(5.879932480491418), np.float64(5.874879094762575), np.float64(5.869843911806385), np.float64(5.8648268653129305), np.float64(5.859827889932181), np.float64(5.85484692057229), np.float64(5.849883892376587), np.float64(5.844938740722034), np.float64(5.840011401218361), np.float64(5.835101809707226), np.float64(5.830209902261388), np.float64(5.825335615183863), np.float64(5.820478885007099), np.float64(5.815639648492154), np.float64(5.810817842627869), np.float64(5.806013404630044), np.float64(5.801226271940628), np.float64(5.7964563822269), np.float64(5.7917036733806535), np.float64(5.7869680835173956), np.float64(5.782249550975539), np.float64(5.777548014315596), np.float64(5.772863412319381), np.float64(5.768195683989212), np.float64(5.76354476854712), np.float
# ...

# %%
user_input_of_population= float(input("Enter the population of city: "))
print("The predicted profit for the city is:", theta[0] + theta[1] * user_input_of_population)
print("theta0 is :",theta[0])
print("theta1 is :",theta[1])
# Out:
# The predicted profit for the city is: 0.0
# theta0 is : 0.0
# theta1 is : 0.0

# %%
#3d plot of weights and biases along withcost function
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D




fig =plt.figure(figsize=(10,10))    
ax=fig.add_subplot(111,projection='3d')

ax.scatter([i[0] for i in theta],[i[1] for i in thetavals],costs)
ax.set_xlabel('theta0')
ax.set_ylabel('theta1')
ax.set_zlabel('cost')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 17
#      14 fig =plt.figure(figsize=(10,10))
#      15 ax=fig.add_subplot(111,projection='3d')
# ---> 17 ax.scatter([i[0] for i in thetavals],[i[1] for i in thetavals],costs)
#      18 ax.set_xlabel('theta0')
#      19 ax.set_ylabel('theta1')
#
# File ~/Desktop/jklu_ml/jkluML/lib64/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
# ...
